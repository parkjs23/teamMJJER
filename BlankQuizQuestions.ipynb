# %% [markdown]
# # **Quiz Questions**

# %% [markdown]
# **Quiz Overview:**
#
#
# 1.   Q1-Q4: Calculus Review
# 2.   Q5-Q7: Gradient Descent
# 3.   Q8-Q9: Stochastic Gradient Descent
# 4.   Q10-Q11: Loss Functions
# 5.   Q12-Q13: Variations on GD

# %% [markdown]
# **Part 1: Calculus Review**
#
# In this section, we will review basic derivatives and gradients to prepare for stochastic gradient descent. Along the way, we will try to build some intuition for the purpose of derivatives. First let's practice some derivatives.

# %% [markdown]
# **Question 1)** Take the derivatives of the following functions.
#
# 1.1: f(x) = sin(x)
#
# ANSWER =
#
#
# 1.2: f(x) = ln(x)
#
# ANSWER =
#
#
# 1.3: f(x) = (6x^3-x)(10-20x)
#
# ANSWER =
#
#
# 1.4: f(x)=ln(x−4+x4)
#
# ANSWER =

# %% [markdown]
# **Question 2)** Let's now visualize the graphs. Find the derivative of f(x) = ln(x) to find the equation of the tangent line. Implement the line function which will define the tangent line.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-15,15,100)
y = np.log(x)

# Define tangent line
# y = m*(x - x1) + y1
def line(x, x1, y1):
  # YOUR CODE HERE
  

plt.plot(x, y, linewidth=2.0) 
plt.plot(x, line(x, 5, np.log(5)), 'C1--', linewidth = 2)
# Out:
#   File "<ipython-input-1-f96466ec034e>", line 13
#     plt.plot(x, y, linewidth=2.0)
#       ^
# IndentationError: expected an indented block

# %% [markdown]
# **Question 3)** What does this tangent line tell us?
#
# ANSWER:

# %% [markdown]
# Question 4) Now let's move on to multivariable calculus. Find the gradient vector. Afterwards, describe where the gradient would be zero in the plot below in words.
#
# f(x,y)= x^2 - xy
#
# ANSWER = ![Screen Shot 2020-11-24 at 1.15.19 PM.png](data:image/png;base64,...)

# %%
def f(x, y):
  return (x ** 2) - x * y  

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %% [markdown]
# ANSWER:

# %% [markdown]
# **Question 4)** Match the follow images with the different points.

# %% [markdown]
# ![Screen Shot 2020-11-24 at 4.31.52 PM.png](data:image/png;base64,...)

# %% [markdown]
# local minima: YOUR ANSWER HERE
#
# local maxima: YOUR ANSWER HERE
#
# negative slope: YOUR ANSWER HERE
#
# positive slope: YOUR ANSWER HERE
#
# not differentiable: YOUR ANSWER HERE

# %% [markdown]
# **Question 5)** Briefly explain the principle of the gradient descent algorithm and define any constants and variables involved.
#
# **Answer:**

# %% [markdown]
# **Question 6)** Write the update equations and compute the gradients for the following loss functions:
#
#
# 1.   OLS L2 Loss: $L(w)=\sum_{i=1}^n (x_i^Tw - y_i)^2$
#
# Answer:
# 2.   Cross-Entropy Loss: $L(w) = -(y_ilog(x_i^Tw) + (1-y_i)log(1 - x_i^Tw))$
#
# Answer:
# 3.   $L(w)=\frac{1}{N}\sum_{i=1}^n (x_i^T)^2w^2 - log(y_i))$
#
# Answer:

# %% [markdown]
# **Question 7)** List the advantages and disadvantages of regular gradient descent, batch gradient descent, mini-batch gradient descent, and stochastic gradient descent. Also include the impact on total error at every step of the four methods.
#
# **Answer:**

# %% [markdown]
# **Question 8)** Match the three types of gradient descent with each line on the convergence graph:

# %% [markdown]
# ![lU3sx.png](data:image/png;base64,...)

# %% [markdown]
# **A:** YOUR ANSWER HERE
#
# **B:** YOUR ANSWER HERE
#
# **C:** YOUR ANSWER HERE

# %% [markdown]
# **Question 9)** Explain the effect of learning rate on the SGD algorithm. How does the magnitude of the step size affect optimal convergence?
#
# **Answer:**

# %% [markdown]
# **Question 10)** Identify and write each of the loss functions from their graphs and specify what this loss function is used for i.e regression or classification:

# %% [markdown]
# ![Screenshot 2020-11-26 182324.png](data:image/png;base64,...)

# %% [markdown]
# **A.** YOUR ANSWER HERE
#
# **B.** YOUR ANSWER HERE
#
# **C.** YOUR ANSWER HERE
#
# **D.** YOUR ANSWER HERE

# %% [markdown]
# **Question 11)** To make the SGD algoritm more efficient we can add a regularization term to our loss function that will give us a different optimal solution. ![VBTK0.png](data:image/png;base64,...)
#
# From the two options above which of these regularization terms (L1 or L2) would you use to obtain a smooth gradient to use in the SGD algorithm?
#
# Answer:

# %% [markdown]
# **Question 12)** Imagine we are trying to find the optimum of the function $f(x) = x^{2}$ starting from the point $x = 100.$ Find the number of steps it takes to get to within $10^{-6}$ of the optimum value of $x = 0$ with both gradient descent with $\eta = 0.01$ and with momentum-based descent with $\eta$ set to the same value, $\gamma = 0.9,$ and an initial velocity of $v^{0} = 0.1.$ What do you notice?

# %% [markdown]
# **Question 13)** Is the ADAM optimization update rule given in the notes entirely correct? If not, how do we fix it, and why do we need to do this? Once you're done, proceed to the coding assignment and implement ADAM!
